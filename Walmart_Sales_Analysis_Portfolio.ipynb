# %% [markdown]
# # **Walmart Sales Analysis** 📈
#
# ## Project Overview
# This project analyzes historical sales data from Walmart stores across the U.S. to identify trends, performance patterns,insights and the influence of holidays and external factors such as unemployment and fuel prices.
#
# ## Business Objectives
#
# - Understand sales trends over time
# - Identify top-performing stores
# - Analyze the impact of holidays on sales
# - Explore how external factors like fuel price and unemployment affect sales

# %% [markdown]
# 📥 **Load the Dataset**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('Walmart_Sales.csv')
df.head()
df.info()

# %% [markdown]
# 🧹 **Data Cleaning & Preprocessing**

# %%
df['Date'] = pd.to_datetime(df['Date'])
df = df.sort_values('Date')

# %% [markdown]
# 🗓️ **Sales Trend Over Time**

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,5))

plt.plot(monthly_sales['YearMonth'], monthly_sales['Weekly_Sales'], label='Monthly Sales', color='green')

# Highlighting top months
for i in range(len(top_months)):
    date = top_months.iloc[i]['YearMonth']
    sales = top_months.iloc[i]['Weekly_Sales']
    plt.scatter(date, sales, color='red', s=100, label='Peak Month' if i == 0 else "")
    plt.text(date, sales + 5e6, date.strftime('%b %Y'), ha='center', fontsize=9, color='darkred')

plt.title('Monthly Sales Trend with Peak Months Highlighted', fontsize=16)
plt.xlabel('Month')
plt.ylabel('Total Sales')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# 🎉 **Holiday Impact**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))
sns.barplot(
    data=holiday_sales,
    x='Holiday_Flag',
    y='Weekly_Sales',
    hue='Holiday_Flag',
    palette='Set2',
    legend=False
)

plt.title('Average Weekly Sales: Holiday vs Non-Holiday Weeks', fontsize=14)
plt.ylabel('Average Weekly Sales')
plt.xlabel('Week Type')
plt.tight_layout()
plt.show()

# %% [markdown]
# 🏪 **Store-Wise Performance**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

top_10 = store_sales.head(10)

plt.figure(figsize=(10, 6))
sns.barplot(
    data=top_10,
    x='Store',
    y='Total_Sales',
    hue='Store',
    palette='Blues_d',
    legend=False
)

plt.title('Top 10 Stores by Total Sales', fontsize=14)
plt.xlabel('Store')
plt.ylabel('Total Sales')
plt.tight_layout()
plt.show()

# %%
top_avg = store_sales.sort_values(by='Average_Weekly_Sales', ascending=False).head(10)

plt.figure(figsize=(10, 6))
sns.barplot(
    data=top_avg,
    x='Store',
    y='Average_Weekly_Sales',
    hue='Store',
    palette='Greens_d',
    legend=False
)

plt.title('Top 10 Stores by Average Weekly Sales', fontsize=14)
plt.xlabel('Store')
plt.ylabel('Average Weekly Sales')
plt.tight_layout()
plt.show()

# %%
top_holiday_impact = store_comparison.head(10).reset_index()

import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 6))
sns.barplot(
    data=top_holiday_impact,
    x='Store',
    y='Difference',
    hue='Store',
    palette='OrRd',
    legend=False
)

plt.title('Top 10 Stores with Highest Holiday Sales Boost', fontsize=14)
plt.ylabel('Increase in Avg Sales (Holiday - Non-Holiday)')
plt.xlabel('Store')
plt.tight_layout()
plt.show()

# %% [markdown]
# 🌦️**External Factor Correlation**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(6,4))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)

plt.title('Correlation Between Sales and External Factors')
plt.tight_layout()

# Save the heatmap
plt.savefig('correlation_heatmap.png', dpi=300)
plt.show()

# %% [markdown]
# 🔍 **Key Findings**
#
# *  December consistently shows the highest sales.
# *  Holidays like Christmas and Superbowl significantly increase sales.
# *  Store 4, 14, and 20 consistently outperform others.
# *  Unemployment has a weak negative correlation (-0.11), meaning higher unemployment slightly reduces sales.Fuel Price, Temperature, and CPI have almost no correlation with sales.
# *  Holiday periods and seasonal events significantly impact Walmart’s revenue
#
# ✅ **Conclusion**
#
# This analysis helps Walmart understand which stores and seasons bring high revenue. It also highlights where external economic factors have limited influence, pointing toward the importance of internal strategies and seasonal promotions.
#
# Future work could include sales forecasting or regional segmentation.
